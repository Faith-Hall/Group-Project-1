# %%
# Import dependencies 
import pandas as pd
from pathlib import Path

# %%
# reference file path
Energy_path = Path("Resources/owid-energy-data.csv")
# import as df
energy_df = pd.read_csv(Energy_path)
energy_df
# Out:
#              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 22007                      NaN                      NaN
# 22008                      NaN                      NaN
# 22009                      NaN                      NaN
# 22010                      NaN                      NaN
# 22011                      NaN                      NaN
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                          NaN                  NaN                      NaN
# 1                          NaN                  NaN                      NaN
# 2                          NaN                  NaN                      NaN
# 3                          NaN                  NaN                      NaN
# 4                          NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# 22007                      NaN                  NaN                   25.910
# 22008                      NaN                  NaN                   24.748
# 22009                      NaN                  NaN                   22.336
# 22010                      NaN                  NaN                   23.760
# 22011                      NaN                  NaN                      NaN
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000                 NaN                   NaN
# 1      ...             0.000                 NaN                   NaN
# 2      ...             0.000                 NaN                   NaN
# 3      ...             0.000                 NaN                   NaN
# 4      ...             0.000                 NaN                   NaN
# ...    ...               ...                 ...                   ...
# 22007  ...             0.218                 NaN                   NaN
# 22008  ...             0.364                 NaN                   NaN
# 22009  ...             0.395                 NaN                   NaN
# 22010  ...             0.498                 NaN                   NaN
# 22011  ...               NaN                 NaN                   NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 22007                   NaN               NaN                   0.0
# 22008                   NaN               NaN                   0.0
# 22009                   NaN               NaN                   0.0
# 22010                   NaN               NaN                   0.0
# 22011                   NaN               NaN                   NaN
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                   0.0                     NaN              0.0
# 1                   0.0                     NaN              0.0
# 2                   0.0                     NaN              0.0
# 3                   0.0                     NaN              0.0
# 4                   0.0                     NaN              0.0
# ...                 ...                     ...              ...
# 22007               0.0                     NaN              0.0
# 22008               0.0                     NaN              0.0
# 22009               0.0                     NaN              0.0
# 22010               0.0                     NaN              0.0
# 22011               NaN                     NaN              NaN
#
#        wind_share_energy
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 22007                NaN
# 22008                NaN
# 22009                NaN
# 22010                NaN
# 22011                NaN
#
# [22012 rows x 129 columns]

# %%
Demo_path = Path("Resources/WPP2022_Demographic_Indicators_Medium.csv")
Demo_df = pd.read_csv(Demo_path)
# Out:
# C:\Users\13202\AppData\Local\Temp\ipykernel_11212\189350840.py:2: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   Demo_df = pd.read_csv(Demo_path)

# %%
Demo_df.columns

LE_columns = [col for col in Demo_df.columns if col.startswith("LE") and "Male" not in col and "Female" not in col]
LE_columns
# Out:
# ['LEx', 'LE15', 'LE65', 'LE80']

# %%
Demo_df.columns
# Out:
# Index(['SortOrder', 'LocID', 'Notes', 'ISO3_code', 'ISO2_code', 'SDMX_code',
#        'LocTypeID', 'LocTypeName', 'ParentID', 'Location', 'VarID', 'Variant',
#        'Time', 'TPopulation1Jan', 'TPopulation1July', 'TPopulationMale1July',
#        'TPopulationFemale1July', 'PopDensity', 'PopSexRatio', 'MedianAgePop',
#        'NatChange', 'NatChangeRT', 'PopChange', 'PopGrowthRate',
#        'DoublingTime', 'Births', 'Births1519', 'CBR', 'TFR', 'NRR', 'MAC',
#        'SRB', 'Deaths', 'DeathsMale', 'DeathsFemale', 'CDR', 'LEx', 'LExMale',
#        'LExFemale', 'LE15', 'LE15Male', 'LE15Female', 'LE65', 'LE65Male',
#        'LE65Female', 'LE80', 'LE80Male', 'LE80Female', 'InfantDeaths', 'IMR',
#        'LBsurvivingAge1', 'Under5Deaths', 'Q5', 'Q0040', 'Q0040Male',
#        'Q0040Female', 'Q0060', 'Q0060Male', 'Q0060Female', 'Q1550',
#        'Q1550Male', 'Q1550Female', 'Q1560', 'Q1560Male', 'Q1560Female',
#        'NetMigrations', 'CNMR'],
#       dtype='object')

# %%
Meta_columns = ['SortOrder', 'Location', 'Time']
Meta_columns
# Out:
# ['SortOrder', 'Location', 'Time']

# %%
# Concatenate meta columns and life expectancy columns
Demo_df = Demo_df[Meta_columns + LE_columns]
Demo_df
# Out:
#        SortOrder                   Location  Time      LEx     LE15     LE65  \
# 0              1                      World  1950  46.4643  47.0395  11.2965
# 1              1                      World  1951  47.1440  47.5028  11.3369
# 2              1                      World  1952  48.2311  48.2552  11.5593
# 3              1                      World  1953  48.8024  48.6073  11.6337
# 4              1                      World  1954  49.5919  49.0909  11.8152
# ...          ...                        ...   ...      ...      ...      ...
# 43467        290  Wallis and Futuna Islands  2097  89.2802  74.6892  25.9523
# 43468        290  Wallis and Futuna Islands  2098  89.4087  74.8108  26.0540
# 43469        290  Wallis and Futuna Islands  2099  89.5113  74.9084  26.1357
# 43470        290  Wallis and Futuna Islands  2100  89.6067  74.9994  26.2127
# 43471        290  Wallis and Futuna Islands  2101      NaN      NaN      NaN
#
#           LE80
# 0       5.0199
# 1       5.0145
# 2       5.1412
# 3       5.1490
# 4       5.2582
# ...        ...
# 43467  13.7656
# 43468  13.8367
# 43469  13.8930
# 43470  13.9470
# 43471      NaN
#
# [43472 rows x 7 columns]

# %%
# ?
Demo_df["Location"].value_counts()
# Out:
# Latin America and the Caribbean    304
# Australia/New Zealand              304
# World                              152
# Spain                              152
# Liechtenstein                      152
#                                   ...
# Southern Asia                      152
# Afghanistan                        152
# Bangladesh                         152
# Bhutan                             152
# Wallis and Futuna Islands          152
# Name: Location, Length: 284, dtype: int64

# %%
# Renaming columns
Demo_df.rename(columns={"SortOrder": "Record Counter","Time": "Year"},inplace=True)
Demo_df
# Out:
#        Record Counter                   Location  Year      LEx     LE15  \
# 0                   1                      World  1950  46.4643  47.0395
# 1                   1                      World  1951  47.1440  47.5028
# 2                   1                      World  1952  48.2311  48.2552
# 3                   1                      World  1953  48.8024  48.6073
# 4                   1                      World  1954  49.5919  49.0909
# ...               ...                        ...   ...      ...      ...
# 43467             290  Wallis and Futuna Islands  2097  89.2802  74.6892
# 43468             290  Wallis and Futuna Islands  2098  89.4087  74.8108
# 43469             290  Wallis and Futuna Islands  2099  89.5113  74.9084
# 43470             290  Wallis and Futuna Islands  2100  89.6067  74.9994
# 43471             290  Wallis and Futuna Islands  2101      NaN      NaN
#
#           LE65     LE80
# 0      11.2965   5.0199
# 1      11.3369   5.0145
# 2      11.5593   5.1412
# 3      11.6337   5.1490
# 4      11.8152   5.2582
# ...        ...      ...
# 43467  25.9523  13.7656
# 43468  26.0540  13.8367
# 43469  26.1357  13.8930
# 43470  26.2127  13.9470
# 43471      NaN      NaN
#
# [43472 rows x 7 columns]

# %%
# Filter Demo years to 2022 and earlier
Demo_df[(Demo_df['Year'] <= 2022)]
# Out:
#        Record Counter                   Location  Year      LEx     LE15  \
# 0                   1                      World  1950  46.4643  47.0395
# 1                   1                      World  1951  47.1440  47.5028
# 2                   1                      World  1952  48.2311  48.2552
# 3                   1                      World  1953  48.8024  48.6073
# 4                   1                      World  1954  49.5919  49.0909
# ...               ...                        ...   ...      ...      ...
# 43388             290  Wallis and Futuna Islands  2018  77.8613  64.0298
# 43389             290  Wallis and Futuna Islands  2019  79.6167  65.6346
# 43390             290  Wallis and Futuna Islands  2020  78.7639  64.8531
# 43391             290  Wallis and Futuna Islands  2021  78.4396  64.4767
# 43392             290  Wallis and Futuna Islands  2022  80.0153  66.0020
#
#           LE65    LE80
# 0      11.2965  5.0199
# 1      11.3369  5.0145
# 2      11.5593  5.1412
# 3      11.6337  5.1490
# 4      11.8152  5.2582
# ...        ...     ...
# 43388  17.7158  8.6228
# 43389  18.8345  9.2126
# 43390  18.2604  8.8750
# 43391  17.9316  8.7685
# 43392  19.0909  9.3542
#
# [20878 rows x 7 columns]

# %%
# Filter energy df years
energy_df[(energy_df['year'] >= 1950)]
# Out:
#              country  year iso_code  population           gdp  \
# 0      ASEAN (Ember)  2000      NaN         NaN           NaN
# 1      ASEAN (Ember)  2001      NaN         NaN           NaN
# 2      ASEAN (Ember)  2002      NaN         NaN           NaN
# 3      ASEAN (Ember)  2003      NaN         NaN           NaN
# 4      ASEAN (Ember)  2004      NaN         NaN           NaN
# ...              ...   ...      ...         ...           ...
# 22007       Zimbabwe  2018      ZWE  15052191.0  2.271535e+10
# 22008       Zimbabwe  2019      ZWE  15354606.0           NaN
# 22009       Zimbabwe  2020      ZWE  15669663.0           NaN
# 22010       Zimbabwe  2021      ZWE  15993525.0           NaN
# 22011       Zimbabwe  2022      ZWE  16320539.0           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 22007                      NaN                      NaN
# 22008                      NaN                      NaN
# 22009                      NaN                      NaN
# 22010                      NaN                      NaN
# 22011                      NaN                      NaN
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                          NaN                  NaN                      NaN
# 1                          NaN                  NaN                      NaN
# 2                          NaN                  NaN                      NaN
# 3                          NaN                  NaN                      NaN
# 4                          NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# 22007                      NaN                  NaN                   25.910
# 22008                      NaN                  NaN                   24.748
# 22009                      NaN                  NaN                   22.336
# 22010                      NaN                  NaN                   23.760
# 22011                      NaN                  NaN                      NaN
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000                 NaN                   NaN
# 1      ...             0.000                 NaN                   NaN
# 2      ...             0.000                 NaN                   NaN
# 3      ...             0.000                 NaN                   NaN
# 4      ...             0.000                 NaN                   NaN
# ...    ...               ...                 ...                   ...
# 22007  ...             0.218                 NaN                   NaN
# 22008  ...             0.364                 NaN                   NaN
# 22009  ...             0.395                 NaN                   NaN
# 22010  ...             0.498                 NaN                   NaN
# 22011  ...               NaN                 NaN                   NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 22007                   NaN               NaN                   0.0
# 22008                   NaN               NaN                   0.0
# 22009                   NaN               NaN                   0.0
# 22010                   NaN               NaN                   0.0
# 22011                   NaN               NaN                   NaN
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                   0.0                     NaN              0.0
# 1                   0.0                     NaN              0.0
# 2                   0.0                     NaN              0.0
# 3                   0.0                     NaN              0.0
# 4                   0.0                     NaN              0.0
# ...                 ...                     ...              ...
# 22007               0.0                     NaN              0.0
# 22008               0.0                     NaN              0.0
# 22009               0.0                     NaN              0.0
# 22010               0.0                     NaN              0.0
# 22011               NaN                     NaN              NaN
#
#        wind_share_energy
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 22007                NaN
# 22008                NaN
# 22009                NaN
# 22010                NaN
# 22011                NaN
#
# [16112 rows x 129 columns]

# %%
energy_df.columns
# Out:
# Index(['country', 'year', 'iso_code', 'population', 'gdp',
#        'biofuel_cons_change_pct', 'biofuel_cons_change_twh',
#        'biofuel_cons_per_capita', 'biofuel_consumption',
#        'biofuel_elec_per_capita',
#        ...
#        'solar_share_elec', 'solar_share_energy', 'wind_cons_change_pct',
#        'wind_cons_change_twh', 'wind_consumption', 'wind_elec_per_capita',
#        'wind_electricity', 'wind_energy_per_capita', 'wind_share_elec',
#        'wind_share_energy'],
#       dtype='object', length=129)

# %%
energy_meta_columns = ['country', 'year', 'population', 'energy_per_capita', 'gas_energy_per_capita', 'hydro_elec_per_capita', 'nuclear_elec_per_capita']
# Out:
# ['country',
#  'year',
#  'population',
#  'energy_per_capita',
#  'gas_energy_per_capita',
#  'hydro_elec_per_capita',
#  'nuclear_elec_per_capita']
